# %% [markdown]
# ## Ex 40

# %%
class Song(object):
    
    def __init__(self, lyrics):
        self.lyrics = lyrics
        
    def sing_me_a_song(self):
        for line in self.lyrics:
            print(line)

# %%
happy_bday = Song(["Happy birthday to you",
                  "I don't want to get sued",
                  "So I'll stop right there"])

bulls_on_parade = Song(["They rally around tha family",
                       "With pockets full of shells"])

happy_bday.sing_me_a_song()

bulls_on_parade.sing_me_a_song()
# Out:
# Happy birthday to you
# I don't want to get sued
# So I'll stop right there
# They rally around tha family
# With pockets full of shells

# %%
class touchOf(object):
    
    def __init__(self, lyrics, wheelies):
        self.lyrics = lyrics
        self.wheelies = wheelies
        self.newVar = self.lyrics + self.wheelies
        
    def sing_me_a_song(self,string1,string2):
        print(f"WHEELIES BRO {self.wheelies}")
   
        print(self.newVar)   
        print(f'string 1 + string 2 is {string1 + string2}')
        plt.plot([1,2,3,4,5],[12,14,17,18,19])
        plt.xlabel(self.wheelies)
        plt.show()

# %%
import matplotlib.pyplot as plt

tester = touchOf("They rally around tha family", 'sick clouds bro')

tester.sing_me_a_song('whoa bro'+" ",'sick clouds')

lift_yourself = touchOf("scoopity", "stuffed crust pizza")

lift_yourself.sing_me_a_song('back off man','dont roll up on me')
# Out:
# WHEELIES BRO sick clouds bro
# They rally around tha familysick clouds bro
# string 1 + string 2 is whoa bro sick clouds
# WHEELIES BRO stuffed crust pizza
# scoopitystuffed crust pizza
# string 1 + string 2 is back off mandont roll up on me
